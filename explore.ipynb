# %%
import psycopg2

conn = psycopg2.connect(
    dbname="beta_base_db",
    user="psqlsynthadmin",
    password="PSQL$ynth#2024",
    host="base-report-synth-postgredb.cb6ae20mupdy.ap-south-1.rds.amazonaws.com",
    port="5432"
)

# %%
import pandas as pd
df = pd.read_sql("SELECT datname FROM pg_database WHERE datistemplate = false;", conn)
df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19512\1875049075.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT datname FROM pg_database WHERE datistemplate = false;", conn)
#                   datname
# 0                postgres
# 1                login_db
# 2        report_server_db
# 3                 base_db
# 4              library_db
# 5   beta_report_server_db
# 6            beta_base_db
# 7           beta_login_db
# 8         beta_library_db
# 9                rdsadmin
# 10                 r&d_db
# 11     leadershipinsights

# %%
cur = conn.cursor()
cur.execute("""
    SELECT table_name 
    FROM information_schema.tables 
    WHERE table_schema = 'public';
""")
tables = cur.fetchall()

print("Tables:")
for table in tables:
    print(f"- {table[0]}")

cur.close()
conn.close()
# Out:
# Tables:
# - trn_comp_copo
# - weekly_time_table
# - user_inputs
# - app_version
# - class_room_master
# - choices
# - class_teacher_master
# - categories
# - course_outcome
# - form_questions
# - generic_master
# - feedback_form
# - lesson_master
# - mst_academic_year
# - mst_admission-year
# - programme_outcome
# - mst_course
# - mst_subject
# - mst_programme
# - online_courses
# - mst_student_registration
# - time_slot
# - time_slot_master
# - public_holiday_master
# - responses
# - subject_teacher_master
# - generic_master_data
# - exam_paper_map_co
# - programme_sub_outcome
# - co_po_mapping
# - course_outcome_wise_percentage
# - mst_curriculum_year
# - weekly_off_master
# - co_po_subject_wise_avg
# - subject_master
# - question_paper_set
# - subject_faculty
# - chapter_master

# %%
import psycopg2

conn = psycopg2.connect(
    dbname="beta_base_db",
    user="psqlsynthadmin",
    password="PSQL$ynth#2024",
    host="base-report-synth-postgredb.cb6ae20mupdy.ap-south-1.rds.amazonaws.com",
    port="5432"
)
# Step 1: Get master_id for 'subject'
query_subject_id = """
    SELECT id FROM public.generic_master WHERE name = 'Subject';
"""
subject_master_id = pd.read_sql(query_subject_id, conn).iloc[0]['id']

# Step 2: Get all subject values
query_subjects = f"""
    SELECT id, name 
    FROM public.generic_master_data 
    WHERE master_id = {subject_master_id};
"""
subjects_df = pd.read_sql(query_subjects, conn)
subjects_df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19512\183319698.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   subject_master_id = pd.read_sql(query_subject_id, conn).iloc[0]['id']
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19512\183319698.py:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   subjects_df = pd.read_sql(query_subjects, conn)
#      id                                    name
# 0     7                           Mathematics-I
# 1    36                 ENGINEERING PHYSICS - I
# 2    47                   Engineering Chemistry
# 3    67  Data Communication & Computer Networks
# 4    60               Physics Chemistry Lab - I
# ...

# %%
subject_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 subject_df.head()
#
# NameError: name 'subject_df' is not defined
